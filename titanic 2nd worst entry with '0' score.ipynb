# %%
#loading need libraries
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
from sklearn.preprocessing import StandardScaler,RobustScaler
from sklearn import preprocessing
# %matplotlib inline

# %%
# load data
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(train.isnull().sum().sort_values(ascending=False))


print(test.isnull().sum().sort_values(ascending=False))
# Out:
# Cabin          687
# Age            177
# Embarked         2
# Fare             0
# Ticket           0
# Parch            0
# SibSp            0
# Sex              0
# Name             0
# Pclass           0
# Survived         0
# PassengerId      0
# dtype: int64
# Cabin          327
# Age             86
# Fare             1
# Embarked         0
# Ticket           0
# Parch            0
# SibSp            0
# Sex              0
# Name             0
# Pclass           0
# PassengerId      0
# dtype: int64

# %%
train = train.drop('PassengerId',axis=1)
test = test.drop('PassengerId',axis=1)

# %%
print(train.shape),
print(test.shape)
# Out:
# (891, 11)
# (418, 10)

# %%
# create a new feature to extract title names from the Name column
train['Title'] = train.Name.apply(lambda name: name.split(',')[1].split('.')[0].strip())
# create a new feature to extract title names from the Name column
test['Title'] = test.Name.apply(lambda name: name.split(',')[1].split('.')[0].strip())

# %%
train.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked Title
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S    Mr
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C   Mrs
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Miss
# 3  female  35.0      1      0            113803  53.1000  C123        S   Mrs
# 4    male  35.0      0      0            373450   8.0500   NaN        S    Mr

# %%
test.head()
# Out:
#    Pclass                                          Name     Sex   Age  SibSp  \
# 0       3                              Kelly, Mr. James    male  34.5      0
# 1       3              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2       2                     Myles, Mr. Thomas Francis    male  62.0      0
# 3       3                              Wirz, Mr. Albert    male  27.0      0
# 4       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
#
#    Parch   Ticket     Fare Cabin Embarked Title
# 0      0   330911   7.8292   NaN        Q    Mr
# 1      0   363272   7.0000   NaN        S   Mrs
# 2      0   240276   9.6875   NaN        Q    Mr
# 3      0   315154   8.6625   NaN        S    Mr
# 4      1  3101298  12.2875   NaN        S   Mrs

# %%
# show count of titles
print("There are {} unique titles.".format(train.Title.nunique()))
# show unique titles
print("\n", train.Title.unique())

# show count of titles
print("There are {} unique titles.".format(test.Title.nunique()))
# show unique titles
print("\n", test.Title.unique())
# Out:
# There are 17 unique titles.
#
#  ['Mr' 'Mrs' 'Miss' 'Master' 'Don' 'Rev' 'Dr' 'Mme' 'Ms' 'Major' 'Lady'
#  'Sir' 'Mlle' 'Col' 'Capt' 'the Countess' 'Jonkheer']
# There are 9 unique titles.
#
#  ['Mr' 'Mrs' 'Miss' 'Master' 'Ms' 'Col' 'Rev' 'Dr' 'Dona']

# %%
# normalize the titles
normalized_titles = {
    "Capt":       "Officer",
    "Col":        "Officer",
    "Major":      "Officer",
    "Jonkheer":   "Royalty",
    "Don":        "Royalty",
    "Sir" :       "Royalty",
    "Dr":         "Officer",
    "Rev":        "Officer",
    "the Countess":"Royalty",
    "Dona":       "Royalty",
    "Mme":        "Mrs",
    "Mlle":       "Miss",
    "Ms":         "Mrs",
    "Mr" :        "Mr",
    "Mrs" :       "Mrs",
    "Miss" :      "Miss",
    "Master" :    "Master",
    "Lady" :      "Royalty"
}

# %%
# map the normalized titles to the current titles
train.Title = train.Title.map(normalized_titles)

# view value counts for the normalized titles
print(train.Title.value_counts())

# map the normalized titles to the current titles
test.Title = test.Title.map(normalized_titles)
# view value counts for the normalized titles
print(test.Title.value_counts())
# Out:
# Mr         517
# Miss       184
# Mrs        127
# Master      40
# Officer     18
# Royalty      5
# Name: Title, dtype: int64
# Mr         240
# Miss        78
# Mrs         73
# Master      21
# Officer      5
# Royalty      1
# Name: Title, dtype: int64

# %%
train = train.drop('Name',axis=1)
test = test.drop('Name',axis=1)

# %%
train.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0         0       3    male  22.0      1      0         A/5 21171   7.2500
# 1         1       1  female  38.0      1      0          PC 17599  71.2833
# 2         1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3         1       1  female  35.0      1      0            113803  53.1000
# 4         0       3    male  35.0      0      0            373450   8.0500
#
#   Cabin Embarked Title
# 0   NaN        S    Mr
# 1   C85        C   Mrs
# 2   NaN        S  Miss
# 3  C123        S   Mrs
# 4   NaN        S    Mr

# %%
test.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked Title
# 0       3    male  34.5      0      0   330911   7.8292   NaN        Q    Mr
# 1       3  female  47.0      1      0   363272   7.0000   NaN        S   Mrs
# 2       2    male  62.0      0      0   240276   9.6875   NaN        Q    Mr
# 3       3    male  27.0      0      0   315154   8.6625   NaN        S    Mr
# 4       3  female  22.0      1      1  3101298  12.2875   NaN        S   Mrs

# %%
train.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# Title        object
# dtype: object

# %%
# group by Sex, Pclass, and Title
grouped = train.groupby(['Sex','Pclass', 'Title'])
# view the median Age by the grouped features
print(grouped.Age.median())

# group by Sex, Pclass, and Title
grouped1 = test.groupby(['Sex','Pclass', 'Title'])
# view the median Age by the grouped features
print(grouped1.Age.median())
# Out:
# Sex     Pclass  Title
# female  1       Miss       30.0
#                 Mrs        40.0
#                 Officer    49.0
#                 Royalty    40.5
#         2       Miss       24.0
#                 Mrs        31.5
#         3       Miss       18.0
#                 Mrs        31.0
# male    1       Master      4.0
#                 Mr         40.0
#                 Officer    51.0
#                 Royalty    40.0
#         2       Master      1.0
#                 Mr         31.0
#                 Officer    46.5
#         3       Master      4.0
#                 Mr         26.0
# Name: Age, dtype: float64
# Sex     Pclass  Title
# female  1       Miss       32.0
#                 Mrs        48.0
#                 Royalty    39.0
#         2       Miss       19.5
#                 Mrs        29.0
#         3       Miss       22.0
#                 Mrs        28.0
# male    1       Master      9.5
#                 Mr         42.0
#                 Officer    53.0
# ...

# %%
# apply the grouped median value on the Age NaN
train.Age = grouped.Age.apply(lambda x: x.fillna(x.median()))
# apply the grouped median value on the Age NaN
test.Age = grouped1.Age.apply(lambda x: x.fillna(x.median()))

# %%
train['Embarked']=train['Embarked'].fillna(train['Embarked'].mode()[0])

# %%
# fill NaN with median fare
test.Fare = test.Fare.fillna(test.Fare.median())

# %%
# fill Cabin NaN with U for unknown
train.Cabin = train.Cabin.fillna('U')
test.Cabin = test.Cabin.fillna('U')

# %%
print(train.isnull().sum().sort_values(ascending=False))


print(test.isnull().sum().sort_values(ascending=False))
# Out:
# Title       0
# Embarked    0
# Cabin       0
# Fare        0
# Ticket      0
# Parch       0
# SibSp       0
# Age         0
# Sex         0
# Pclass      0
# Survived    0
# dtype: int64
# Title       0
# Embarked    0
# Cabin       0
# Fare        0
# Ticket      0
# Parch       0
# SibSp       0
# Age         0
# Sex         0
# Pclass      0
# dtype: int64

# %%
# size of families (including the passenger)
train['FamilySize'] = train.Parch + train.SibSp + 1
# size of families (including the passenger)
test['FamilySize'] = test.Parch + train.SibSp + 1

# %%
train.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0         0       3    male  22.0      1      0         A/5 21171   7.2500
# 1         1       1  female  38.0      1      0          PC 17599  71.2833
# 2         1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3         1       1  female  35.0      1      0            113803  53.1000
# 4         0       3    male  35.0      0      0            373450   8.0500
#
#   Cabin Embarked Title  FamilySize
# 0     U        S    Mr           2
# 1   C85        C   Mrs           2
# 2     U        S  Miss           1
# 3  C123        S   Mrs           2
# 4     U        S    Mr           1

# %%
test.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked Title  \
# 0       3    male  34.5      0      0   330911   7.8292     U        Q    Mr
# 1       3  female  47.0      1      0   363272   7.0000     U        S   Mrs
# 2       2    male  62.0      0      0   240276   9.6875     U        Q    Mr
# 3       3    male  27.0      0      0   315154   8.6625     U        S    Mr
# 4       3  female  22.0      1      1  3101298  12.2875     U        S   Mrs
#
#    FamilySize
# 0         2.0
# 1         2.0
# 2         1.0
# 3         2.0
# 4         2.0

# %%
train = train.drop('SibSp',axis=1)
train = train.drop('Parch',axis=1)

test = test.drop('SibSp',axis=1)
test = test.drop('Parch',axis=1)

# %%
train.head()
# Out:
#    Survived  Pclass     Sex   Age            Ticket     Fare Cabin Embarked  \
# 0         0       3    male  22.0         A/5 21171   7.2500     U        S
# 1         1       1  female  38.0          PC 17599  71.2833   C85        C
# 2         1       3  female  26.0  STON/O2. 3101282   7.9250     U        S
# 3         1       1  female  35.0            113803  53.1000  C123        S
# 4         0       3    male  35.0            373450   8.0500     U        S
#
#   Title  FamilySize
# 0    Mr           2
# 1   Mrs           2
# 2  Miss           1
# 3   Mrs           2
# 4    Mr           1

# %%
test.head()
# Out:
#    Pclass     Sex   Age   Ticket     Fare Cabin Embarked Title  FamilySize
# 0       3    male  34.5   330911   7.8292     U        Q    Mr         2.0
# 1       3  female  47.0   363272   7.0000     U        S   Mrs         2.0
# 2       2    male  62.0   240276   9.6875     U        Q    Mr         1.0
# 3       3    male  27.0   315154   8.6625     U        S    Mr         2.0
# 4       3  female  22.0  3101298  12.2875     U        S   Mrs         2.0

# %%
# map first letter of cabin to itself
train.Cabin = train.Cabin.map(lambda x: x[0])

# view normalized count
train.Cabin.value_counts(normalize=True)
# Out:
# U    0.771044
# C    0.066218
# B    0.052750
# D    0.037037
# E    0.035915
# A    0.016835
# F    0.014590
# G    0.004489
# T    0.001122
# Name: Cabin, dtype: float64

# %%
# map first letter of cabin to itself
test.Cabin = test.Cabin.map(lambda x: x[0])

# view normalized count
test.Cabin.value_counts(normalize=True)
# Out:
# U    0.782297
# C    0.083732
# B    0.043062
# D    0.031100
# E    0.021531
# F    0.019139
# A    0.016746
# G    0.002392
# Name: Cabin, dtype: float64

# %%
# merge train and test
df = train.append(test, ignore_index=True)

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age            Ticket     Fare Cabin Embarked  \
# 0       0.0       3    male  22.0         A/5 21171   7.2500     U        S
# 1       1.0       1  female  38.0          PC 17599  71.2833     C        C
# 2       1.0       3  female  26.0  STON/O2. 3101282   7.9250     U        S
# 3       1.0       1  female  35.0            113803  53.1000     C        S
# 4       0.0       3    male  35.0            373450   8.0500     U        S
#
#   Title  FamilySize
# 0    Mr         2.0
# 1   Mrs         2.0
# 2  Miss         1.0
# 3   Mrs         2.0
# 4    Mr         1.0

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Survived      418
# FamilySize      0
# Title           0
# Embarked        0
# Cabin           0
# Fare            0
# Ticket          0
# Age             0
# Sex             0
# Pclass          0
# dtype: int64

# %%
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']
categorical_features
# Out:
# ['Sex', 'Ticket', 'Cabin', 'Embarked', 'Title']

# %%
# Convert the male and female groups to integer form
df.Sex = df.Sex.map({"male": 0, "female":1})

# %%
df.head()
# Out:
#    Survived  Pclass  Sex   Age            Ticket     Fare Cabin Embarked  \
# 0       0.0       3    0  22.0         A/5 21171   7.2500     U        S
# 1       1.0       1    1  38.0          PC 17599  71.2833     C        C
# 2       1.0       3    1  26.0  STON/O2. 3101282   7.9250     U        S
# 3       1.0       1    1  35.0            113803  53.1000     C        S
# 4       0.0       3    0  35.0            373450   8.0500     U        S
#
#   Title  FamilySize
# 0    Mr         2.0
# 1   Mrs         2.0
# 2  Miss         1.0
# 3   Mrs         2.0
# 4    Mr         1.0

# %%
df['Cabin'].unique()
# Out:
# array(['U', 'C', 'E', 'G', 'D', 'A', 'B', 'F', 'T'], dtype=object)

# %%
# Convert the Cabine  to integer form
df.Cabin = df.Cabin.map({'U':0, 'C':1, 'E':2, 'G':3, 'D':4, 'A':5, 'B':6, 'F':7, 'T':8})

# %%
df.head()
# Out:
#    Survived  Pclass  Sex   Age            Ticket     Fare  Cabin Embarked  \
# 0       0.0       3    0  22.0         A/5 21171   7.2500      0        S
# 1       1.0       1    1  38.0          PC 17599  71.2833      1        C
# 2       1.0       3    1  26.0  STON/O2. 3101282   7.9250      0        S
# 3       1.0       1    1  35.0            113803  53.1000      1        S
# 4       0.0       3    0  35.0            373450   8.0500      0        S
#
#   Title  FamilySize
# 0    Mr         2.0
# 1   Mrs         2.0
# 2  Miss         1.0
# 3   Mrs         2.0
# 4    Mr         1.0

# %%
df['Title'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Royalty', 'Officer'], dtype=object)

# %%
df.Title = df.Title.map({'Mr':0, 'Mrs':1, 'Miss':2, 'Master':3, 'Royalty':4, 'Officer':5})

# %%
df = df.drop('Ticket',axis=1)

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
df.Embarked = df.Embarked.map({'S':0, 'C':1, 'Q':2})

# %%
df.head()
# Out:
#    Survived  Pclass  Sex   Age     Fare  Cabin  Embarked  Title  FamilySize
# 0       0.0       3    0  22.0   7.2500      0         0      0         2.0
# 1       1.0       1    1  38.0  71.2833      1         1      1         2.0
# 2       1.0       3    1  26.0   7.9250      0         0      2         1.0
# 3       1.0       1    1  35.0  53.1000      1         0      1         2.0
# 4       0.0       3    0  35.0   8.0500      0         0      0         1.0

# %%
df.dtypes
# Out:
# Survived      float64
# Pclass          int64
# Sex             int64
# Age           float64
# Fare          float64
# Cabin           int64
# Embarked        int64
# Title           int64
# FamilySize    float64
# dtype: object

# %%
df_Train=df.iloc[:891,:]
df_Test=df.iloc[891:,:]

# %%
df_Train.tail()
# Out:
#      Survived  Pclass  Sex   Age   Fare  Cabin  Embarked  Title  FamilySize
# 886       0.0       2    0  27.0  13.00      0         0      5         1.0
# 887       1.0       1    1  19.0  30.00      6         0      2         1.0
# 888       0.0       3    1  18.0  23.45      0         0      2         4.0
# 889       1.0       1    0  26.0  30.00      1         1      0         1.0
# 890       0.0       3    0  32.0   7.75      0         2      0         1.0

# %%
df_Test.head()
# Out:
#      Survived  Pclass  Sex   Age     Fare  Cabin  Embarked  Title  FamilySize
# 891       NaN       3    0  34.5   7.8292      0         2      0         2.0
# 892       NaN       3    1  47.0   7.0000      0         0      1         2.0
# 893       NaN       2    0  62.0   9.6875      0         2      0         1.0
# 894       NaN       3    0  27.0   8.6625      0         0      0         2.0
# 895       NaN       3    1  22.0  12.2875      0         0      1         2.0

# %%
df_Test.drop(['Survived'],axis=1,inplace=True)
# Out:
# C:\Users\ssc\Anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
# create X and y for data and target values
X = df_Train.drop('Survived', axis=1).values
y = df_Train.Survived.values

# %%
# create array for test set
X_test = df_Test

# %%
X
# Out:
# array([[ 3.,  0., 22., ...,  0.,  0.,  2.],
#        [ 1.,  1., 38., ...,  1.,  1.,  2.],
#        [ 3.,  1., 26., ...,  0.,  2.,  1.],
#        ...,
#        [ 3.,  1., 18., ...,  0.,  2.,  4.],
#        [ 1.,  0., 26., ...,  1.,  0.,  1.],
#        [ 3.,  0., 32., ...,  2.,  0.,  1.]])

# %%
# classifier models
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %%
# create param grid object
log_params = dict(
    C = np.logspace(-5, 8, 15),
    penalty = ['l1', 'l2']
)

# %%
# instantiate logistic regressor
log = LogisticRegression()

# load param grid and log model into GridSearcCV
logreg_cv = GridSearchCV(estimator=log, param_grid=log_params, cv=5)

# fit model
logreg_cv.fit(X, y)
# Out:
# C:\Users\ssc\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\ssc\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ssc\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1304, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\ssc\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 443, in _check_solver
#     "got %s penalty." % (solver, penalty))
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# ...

# %%
# Print the tuned parameters and score
print("Tuned Logistic Regression Parameters: {}".format(logreg_cv.best_params_)) 
print("Best score is {}".format(logreg_cv.best_score_))
# Out:
# Tuned Logistic Regression Parameters: {'C': 2275.845926074791, 'penalty': 'l2'}
# Best score is 0.7946017199171428

# %%
# create param grid object
forrest_params = dict(
    max_depth = [n for n in range(9, 14)],
    min_samples_split = [n for n in range(4, 11)],
    min_samples_leaf = [n for n in range(2, 5)],
    n_estimators = [n for n in range(10, 60, 10)],
)

# %%
# instantiate Random Forest model
forrest = RandomForestClassifier()

# %%
# build and fit model
forest_cv = GridSearchCV(estimator=forrest, param_grid=forrest_params, cv=5)
forest_cv.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [9, 10, 11, 12, 13],
#                          'min_samples_leaf': [2, 3, 4],
#                          'min_samples_split': [4, 5, 6, 7, 8, 9, 10],
#                          'n_estimators': [10, 20, 30, 40, 50]})

# %%
# print("Best score: {}".format(forest_model.best_score_))
# print("Optimal params: {}".format(forest_model.best_estimator_))
print("Best score: {}".format(forest_cv.best_score_))
print("Optimal params: {}".format(forest_cv.best_estimator_))
# Out:
# Best score: 0.8439897056054235
# Optimal params: RandomForestClassifier(max_depth=11, min_samples_leaf=3, min_samples_split=9,
#                        n_estimators=40)

# %%
# random forrest prediction on test set
forrest_pred = forest_cv.predict(X_test)

# %%
sample_sub=pd.read_csv('gender_submission.csv')

# %%
sample_sub
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
passengerId = sample_sub.drop('Survived',axis=1)

# %%
passengerId.shape
# Out:
# (418, 1)

# %%
len(forrest_pred)
# Out:
# 418

# %%
pred=pd.DataFrame(forrest_pred)

# %%
datasets=pd.concat([sample_sub['PassengerId'],pred],axis=1)

# %%
# ensure df is in the right format
datasets.head(10)
# Out:
#    PassengerId    0
# 0          892  0.0
# 1          893  0.0
# 2          894  0.0
# 3          895  0.0
# 4          896  1.0
# 5          897  0.0
# 6          898  1.0
# 7          899  0.0
# 8          900  1.0
# 9          901  0.0

# %%
datasets.columns=['PassengerId','Survived']

# %%
datasets.tail()
# Out:
#      PassengerId  Survived
# 413         1305       0.0
# 414         1306       1.0
# 415         1307       0.0
# 416         1308       0.0
# 417         1309       1.0

# %%
datasets.to_csv('sub2RF.csv',index=False)

# %%
sub=pd.read_csv('sub2RF.csv')

# %%
sub
# Out:
#      PassengerId  Survived
# 0            892       0.0
# 1            893       0.0
# 2            894       0.0
# 3            895       0.0
# 4            896       1.0
# ..           ...       ...
# 413         1305       0.0
# 414         1306       1.0
# 415         1307       0.0
# 416         1308       0.0
# 417         1309       1.0
#
# [418 rows x 2 columns]
